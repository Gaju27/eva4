# %%
# !git clone https://github.com/Gaju27/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 1369 (delta 6), reused 0 (delta 0), pack-reused 1337
# Receiving objects: 100% (1369/1369), 211.84 MiB | 42.26 MiB/s, done.
# Resolving deltas: 100% (83/83), done.
# Checking out files: 100% (1237/1237), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave --single-cls
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=True, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-24 21:50:15.145826: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (490 found, 13 missing, 0 empty, 0 duplicate, for 503 images): 100% 503/503 [00:00<00:00, 8851.38it/s]
# Caching images (0.2GB):  70% 352/503 [00:20<00:08, 18.23it/s]libpng warning: iCCP: known incorrect sRGB profile
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave --single-cls
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=True, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-25 03:59:19.797976: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (490 found, 13 missing, 0 empty, 0 duplicate, for 503 images): 100% 503/503 [00:00<00:00, 10136.86it/s]
# Caching images (0.2GB):  70% 354/503 [00:18<00:07, 20.87it/s]libpng warning: iCCP: known incorrect sRGB profile
# ...

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/EVA/pics"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/EVA/pics', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/579 data/customdata/images/i00000.jpg: 320x512 3 Iron_Mans, Done. (0.018s)
# image 2/579 data/customdata/images/i00001.jpg: 384x512 1 Iron_Mans, Done. (0.019s)
# image 3/579 data/customdata/images/i000010.jpg: 512x384 1 Iron_Mans, Done. (0.019s)
# image 4/579 data/customdata/images/i0000100.jpg: 512x320 1 Iron_Mans, Done. (0.019s)
# image 5/579 data/customdata/images/i0000101.jpg: 384x512 2 Iron_Mans, Done. (0.019s)
# ...

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/EVA/iron_out" --source "/content/gdrive/My Drive/EVA/Iron man.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/EVA/iron_out', save_txt=False, source='/content/gdrive/My Drive/EVA/Iron man.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/772) /content/gdrive/My Drive/EVA/Iron man.mp4: 320x512 1 Iron_Mans, Done. (0.017s)
# video 1/1 (2/772) /content/gdrive/My Drive/EVA/Iron man.mp4: 320x512 1 Iron_Mans, Done. (0.016s)
# video 1/1 (3/772) /content/gdrive/My Drive/EVA/Iron man.mp4: 320x512 1 Iron_Mans, Done. (0.016s)
# video 1/1 (4/772) /content/gdrive/My Drive/EVA/Iron man.mp4: 320x512 1 Iron_Mans, Done. (0.016s)
# ...

# %%
# Image(filename='YoloV3/out_out/i00000.jpg', width=600)
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/EVA/iron_out" --source "/content/gdrive/My Drive/EVA/iron man entry.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/EVA/iron_out', save_txt=False, source='/content/gdrive/My Drive/EVA/iron man entry.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/1047) /content/gdrive/My Drive/EVA/iron man entry.mp4: 320x512 Done. (0.017s)
# video 1/1 (2/1047) /content/gdrive/My Drive/EVA/iron man entry.mp4: 320x512 Done. (0.016s)
# video 1/1 (3/1047) /content/gdrive/My Drive/EVA/iron man entry.mp4: 320x512 Done. (0.016s)
# video 1/1 (4/1047) /content/gdrive/My Drive/EVA/iron man entry.mp4: 320x512 Done. (0.016s)
# ...

# %%
# !git add runs/
# !git add results.txt
# !git add test_batch0.png
# !git add results.png
# !git add train_batch0.png
# !git add results.json

# %%
# !git commit -m "trained for 500  images 300 epochs with batch 10"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@8e1fda96e07b.(none)')

# %%
# !git config --global user.email "gajucg@gmail.com"

# %%
# !git commit -m "trained for 500  images 300 epochs with batch 10"
# Out:
# [master b67c982] trained for 500  images 300 epochs with batch 10
#  5 files changed, 300 insertions(+), 3 deletions(-)
#  rewrite results.png (97%)
#  rewrite results.txt (100%)
#  create mode 100644 runs/Apr25_03-59-19_8e1fda96e07b/events.out.tfevents.1587787161.8e1fda96e07b.614.0
#  rewrite test_batch0.png (80%)
#  rewrite train_batch0.png (75%)

# %%
# !git push https://@github.com/Gaju27/YOLO3_iron_man_dataset.git --all
# Out:
# fatal: could not read Password for 'https://github.com': No such device or address

# %%
git init
git add README.md
git commit -m "first commit"
git remote add origin https://github.com/Gaju27/YOLO3_iron_man_dataset.git
git push -u origin master
